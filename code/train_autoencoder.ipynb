# %%
from segan_utils import *
from train_gan import *

# %%
autoencoder = Autoenc(input_shape = [16384, 1], trim_size = 16384)
autoencoder.create_autoencoder()

# %%
autoencoder.autoencoder.summary()
# Out:
# Model: "Autoencoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 16384, 1)]   0
# __________________________________________________________________________________________________
# autoenc_conv_1 (Conv1D)         (None, 8192, 16)     176         input_1[0][0]
# __________________________________________________________________________________________________
# autoenc_ac_1 (PReLU)            (None, 8192, 16)     131072      autoenc_conv_1[0][0]
# __________________________________________________________________________________________________
# autoenc_conv_2 (Conv1D)         (None, 4096, 32)     5152        autoenc_ac_1[0][0]
# __________________________________________________________________________________________________
# ...

# %%
tf.keras.utils.plot_model(autoencoder.autoencoder, to_file = "Pictures/Autoencoder.png")

# %%
autoencoder.train_autoencoder(plot_freq = 2)
# Out:
# ...
# 100%|██████████| 3377/3377 [05:42<00:00,  9.85it/s]
# Epoch 1/5
# 360/360 [==============================] - 39s 99ms/step - loss: 0.0133 - val_loss: 0.0094
# Epoch 2/5
# 360/360 [==============================] - 35s 98ms/step - loss: 0.0090 - val_loss: 0.0080
# Epoch 3/5
# 360/360 [==============================] - 36s 99ms/step - loss: 0.0081 - val_loss: 0.0076
# Epoch 4/5
# 360/360 [==============================] - 36s 99ms/step - loss: 0.0077 - val_loss: 0.0071
# Epoch 5/5
# 360/360 [==============================] - 36s 99ms/step - loss: 0.0073 - val_loss: 0.0090
# (1, 16384, 1)
# (1, 16384, 1)
# Checkpoint created at epoch 5
# INFO:tensorflow:Assets written to: Checkpoint_5_150/assets
# /home/harish/anaconda3/envs/machine_learning/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
# ...
